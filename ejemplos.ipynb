# %%
import pandas as pd
df=pd.read_csv("Airplane_Crashes_and_Fatalities_Since_1908.csv")
df
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3701 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     import pandas as pd
#
#   File c:\Users\SALÓN 202\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\__init__.py:34
#     from pandas.compat import (
#
#   File c:\Users\SALÓN 202\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\compat\__init__.py:27
#     from pandas.compat.numpy import is_numpy_dev
#
#   File c:\Users\SALÓN 202\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\compat\numpy\__init__.py:7
#     from pandas.util.version import Version
#
#   File <string>
#
# SyntaxError: source code string cannot contain null bytes
